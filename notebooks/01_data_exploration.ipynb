# %% [markdown]
# # 01 — Data Exploration
#
# Load raw EEG data for one subject, plot raw signals, inspect annotations and events, and display the channel montage.
#
# **Dataset:** PhysioNet EEG Motor Movement/Imagery (EEGBCI)
# **Task:** Left vs Right hand motor imagery (Runs 3 & 7)
